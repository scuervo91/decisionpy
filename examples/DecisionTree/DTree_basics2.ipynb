# %%
import numpy as np 
from decisionpy.decisiontree import Node
import yaml

# %%
with open('DTree_basicfile.yml','r') as file:
    case_dict = yaml.load(file)
# Out:
# <ipython-input-2-2a474c33f8a9>:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   case_dict = yaml.load(file)

# %%
c = Node(**case_dict)

# %%
c.tree()
# Out:
# ⬛ Accion 💯 Value: -35.0 | ➕ Cum Value: -35.0 |
# ┣━━ 🔻 Paga 💯 Value: 0.0 | ➕ Cum Value: 0 |
# ┣━━ ⚪Demanda 💯 Value: -9.0 | ➕ Cum Value: 0 |
# ┃   ╠══ 🔻 Gana 🎲 Prob: 0.425 | 💯 Value: 45.0 | ➕ Cum Value: 0 |
# ┃   ╚══ 🔻 Pierde 🎲 Prob: 0.575 | 💯 Value: 0.0 | ➕ Cum Value: 0 |
# ┗━━ ⚪Notifica 💯 Value: -1.0 | ➕ Cum Value: 0 |
#     ╠══ ⬛ Negocia 🎲 Prob: 0.5 | 💯 Value: 0 | ➕ Cum Value: 0 |
#     ║   ┣━━ 🔻 Acuerdo 💯 Value: 22.5 | ➕ Cum Value: 0 |
#     ║   ┗━━ ⬛ No Acuerdo 💯 Value: 0 | ➕ Cum Value: 0 |
#     ║       ┣━━ ⚪Demanda 💯 Value: -9.0 | ➕ Cum Value: 0 |
#     ║       ┃   ╠══ 🔻 Gana 🎲 Prob: 0.6 | 💯 Value: 45.0 | ➕ Cum Value: 0 |
#     ║       ┃   ╚══ 🔻 Pierde 🎲 Prob: 0.4 | 💯 Value: 0.0 | ➕ Cum Value: 0 |
#     ║       ┗━━ 🔻 Paga 💯 Value: 0.0 | ➕ Cum Value: 0 |
#     ╚══ ⬛ No_negocia 🎲 Prob: 0.5 | 💯 Value: 0 | ➕ Cum Value: 0 |
#         ┗━━ ⚪Demanda 💯 Value: -9.0 | ➕ Cum Value: 0 |
#             ╠══ 🔻 Gana 🎲 Prob: 0.25 | 💯 Value: 45.0 | ➕ Cum Value: 0 |
#             ╚══ 🔻 Pierde 🎲 Prob: 0.75 | 💯 Value: 0.0 | ➕ Cum Value: 0 |

# %%
c.solve()
# Out:
# -23.625

# %%
c.tree(expand_row=False)
# Out:
# ⬛ Accion 💯 Value: -35.0 | ➕ Cum Value: -35.0 |
#      ⭐ Exp. Value: -23.625 |
# ┣━━ 🚫🔻 Paga 💯 Value: 0.0 | ➕ Cum Value: -35.0 |
# ┃        ⭐ Exp. Value: -35.0 |
# ┣━━ 🚫⚪Demanda 💯 Value: -9.0 | ➕ Cum Value: -44.0 |
# ┃        ⭐ Exp. Value: -24.874999999999996 |
# ┃   ╠══ 🔻 Gana 🎲 Prob: 0.425 | 💯 Value: 45.0 | ➕ Cum Value: 1.0 |
# ┃   ║        ⭐ Exp. Value: 1.0 |
# ┃   ╚══ 🔻 Pierde 🎲 Prob: 0.575 | 💯 Value: 0.0 | ➕ Cum Value: -44.0 |
# ┃            ⭐ Exp. Value: -44.0 |
# ┗━━ ✅⚪Notifica 💯 Value: -1.0 | ➕ Cum Value: -36.0 |
#          ⭐ Exp. Value: -23.625 |
#     ╠══ ⬛ Negocia 🎲 Prob: 0.5 | 💯 Value: 0 | ➕ Cum Value: -36.0 |
#     ║        ⭐ Exp. Value: -13.5 |
#     ║   ┣━━ ✅🔻 Acuerdo 💯 Value: 22.5 | ➕ Cum Value: -13.5 |
#     ║   ┃        ⭐ Exp. Value: -13.5 |
#     ║   ┗━━ 🚫⬛ No Acuerdo 💯 Value: 0 | ➕ Cum Value: -36.0 |
#     ║            ⭐ Exp. Value: -18.0 |
#     ║       ┣━━ ✅⚪Demanda 💯 Value: -9.0 | ➕ Cum Value: -45.0 |
#     ║       ┃        ⭐ Exp. Value: -18.0 |
#     ║       ┃   ╠══ 🔻 Gana 🎲 Prob: 0.6 | 💯 Value: 45.0 | ➕ Cum Value: 0.0 |
#     ║       ┃   ║        ⭐ Exp. Value: 0.0 |
#     ║       ┃   ╚══ 🔻 Pierde 🎲 Prob: 0.4 | 💯 Value: 0.0 | ➕ Cum Value: -45.0 |
#     ║       ┃            ⭐ Exp. Value: -45.0 |
#     ║       ┗━━ 🚫🔻 Paga 💯 Value: 0.0 | ➕ Cum Value: -36.0 |
#     ║                ⭐ Exp. Value: -36.0 |
#     ╚══ ⬛ No_negocia 🎲 Prob: 0.5 | 💯 Value: 0 | ➕ Cum Value: -36.0 |
#              ⭐ Exp. Value: -33.75 |
#         ┗━━ ✅⚪Demanda 💯 Value: -9.0 | ➕ Cum Value: -45.0 |
#                  ⭐ Exp. Value: -33.75 |
#             ╠══ 🔻 Gana 🎲 Prob: 0.25 | 💯 Value: 45.0 | ➕ Cum Value: 0.0 |
#             ║        ⭐ Exp. Value: 0.0 |
#             ╚══ 🔻 Pierde 🎲 Prob: 0.75 | 💯 Value: 0.0 | ➕ Cum Value: -45.0 |
#                      ⭐ Exp. Value: -45.0 |

# %%
0.4*-45
# Out:
# -18.0
